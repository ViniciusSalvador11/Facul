# %% [markdown]
# Vinicius Salvador - 821150867 - Computação gráfica e realidade virtual - Matutino, Terça-feira - Butantã

# %% [markdown]
# Aula 02/04/2024 ->

# %% [markdown]
# Aula 09/04/2024 ->

# %%
import cv2
from google.colab.patches import cv2_imshow
imagem = cv2.imread("/content/85350.jpg")
cv2_imshow(imagem)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
x = 10
y = 100

(azul, verde, vermelho) = imagem[y, x]
print('Vermelho:',vermelho,'Verde:',verde, 'Azul:',azul)
# Out:
# Vermelho: 14 Verde: 18 Azul: 21

# %%
x = 10
y = 100

azul = 255
verde = 255
vermelho = 0
print('Vermelho:',vermelho,'Verde:',verde, 'Azul:',azul)
# Out:
# Vermelho: 0 Verde: 255 Azul: 255

# %%
for y in range (0, imagem.shape[0]):
  for x in range (0, imagem.shape[1]):
    (azul, verde, vermelho) = imagem[y, x]
    print(y, x, 'Vermelho:',vermelho,'Verde:',verde, 'Azul:',azul)
# Out:
# Streaming output truncated to the last 5000 lines.
# 894 249 Vermelho: 87 Verde: 54 Azul: 9
# 894 250 Vermelho: 86 Verde: 54 Azul: 7
# 894 251 Vermelho: 101 Verde: 69 Azul: 8
# 894 252 Vermelho: 136 Verde: 102 Azul: 41
# 894 253 Vermelho: 97 Verde: 59 Azul: 12
# 894 254 Vermelho: 83 Verde: 42 Azul: 0
# 894 255 Vermelho: 116 Verde: 77 Azul: 20
# 894 256 Vermelho: 114 Verde: 81 Azul: 12
# 894 257 Vermelho: 105 Verde: 71 Azul: 10
# 894 258 Vermelho: 96 Verde: 63 Azul: 0
# 894 259 Vermelho: 100 Verde: 66 Azul: 18
# 894 260 Vermelho: 72 Verde: 38 Azul: 3
# 894 261 Vermelho: 82 Verde: 51 Azul: 7
# 894 262 Vermelho: 74 Verde: 45 Azul: 1
# 894 263 Vermelho: 100 Verde: 77 Azul: 9
# 894 264 Vermelho: 87 Verde: 57 Azul: 7
# 894 265 Vermelho: 79 Verde: 47 Azul: 6
# 894 266 Vermelho: 88 Verde: 57 Azul: 11
# 894 267 Vermelho: 97 Verde: 65 Azul: 8
# 894 268 Vermelho: 99 Verde: 64 Azul: 0
# 894 269 Vermelho: 167 Verde: 125 Azul: 53
# 894 270 Vermelho: 218 Verde: 173 Azul: 80
# ...
