# %%
list = ([10, 10, 11, 11, 11, 10, 11, 10, 10, 11, 10, 11],
        [11, 10, 9, 9, 9, 8, 8, 7, 8, 10, 10, 10],
        [10, 10, 6, 2, 2, 1, 1, 1, 1,9, 10,10],
        [11, 10, 5, 2, 2, 3, 3, 3, 1, 8, 10, 10],
        [10, 10, 6, 3, 7, 10, 10, 6, 3, 7, 10, 10],
        [10, 10, 7, 3, 6, 10, 9, 8, 3, 6, 10, 10],
        [10, 10, 9, 1, 5, 9, 1, 4, 1, 6, 10, 10],
        [9, 10, 9, 1, 4, 9, 1, 4, 1, 6, 9, 10],
        [10, 10, 9, 1, 3, 8, 7, 5, 1, 6, 9, 10],
        [10, 10, 10, 1, 1, 2, 2, 1, 0, 6, 8, 10],
        [10, 10, 10, 6, 6, 6, 6, 6, 6, 6, 8, 10],
        [10, 10, 10, 10, 8, 9, 9, 9, 9, 10, 10, 9])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(list, bins=30, color='skyblue', edgecolor='black')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-42037dfc940d> in <cell line: 4>()
#       2 import numpy as np
#       3
# ----> 4 plt.hist(list, bins=30, color='skyblue', edgecolor='black')
#       5 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
#    2646         x, bins=bins, range=range, density=density, weights=weights,
#    2647         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


sns.histplot(list2, bins=30, kde=False, color='lightgreen', edgecolor='black')
# Adding labels and title
plt.xlabel('Values')
plt.ylabel('Density')
plt.title('Customized Histogram with Density Plot')
plt.show()

# %%
from collections import  Counter

def calcular_histograma(lista):
  contador = Counter(lista)
  return dict(contador)

list = ([[10, 10, 11, 11, 11, 10, 11, 10, 10, 11, 10, 11],
        [11, 10, 9, 9, 9, 8, 8, 7, 8, 10, 10, 10],
        [10, 10, 6, 2, 2, 1, 1, 1, 1,9, 10,10],
        [11, 10, 5, 2, 2, 3, 3, 3, 1, 8, 10, 10],
        [10, 10, 6, 3, 7, 10, 10, 6, 3, 7, 10, 10],
        [10, 10, 7, 3, 6, 10, 9, 8, 3, 6, 10, 10],
        [10, 10, 9, 1, 5, 9, 1, 4, 1, 6, 10, 10],
        [9, 10, 9, 1, 4, 9, 1, 4, 1, 6, 9, 10],
        [10, 10, 9, 1, 3, 8, 7, 5, 1, 6, 9, 10],
        [10, 10, 10, 1, 1, 2, 2, 1, 0, 6, 8, 10],
        [10, 10, 10, 6, 6, 6, 6, 6, 6, 6, 8, 10],
        [10, 10, 10, 10, 8, 9, 9, 9, 9, 10, 10, 9]])

histograma = calcular_histograma(list)
print(histograma)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-46e6dcba6723> in <cell line: 20>()
#      18         [10, 10, 10, 10, 8, 9, 9, 9, 9, 10, 10, 9]])
#      19
# ---> 20 histograma = calcular_histograma(list)
#      21 print(histograma)
#
# <ipython-input-25-46e6dcba6723> in calcular_histograma(lista)
#       2
#       3 def calcular_histograma(lista):
# ----> 4   contador = Counter(lista)
#       5   return dict(contador)
#       6
#
# /usr/lib/python3.10/collections/__init__.py in __init__(self, iterable, **kwds)
#     575         '''
#     576         super().__init__()
# --> 577         self.update(iterable, **kwds)
#     578
#     579     def __missing__(self, key):
#
# /usr/lib/python3.10/collections/__init__.py in update(self, iterable, **kwds)
#     668                     super().update(iterable)
#     669             else:
# ...
