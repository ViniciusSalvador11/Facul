# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
from cv.object_detection import draw_bbox


im = cv2.imread('apples.jpg')



bbox, label, conf = cv.detect_common_objects(im)
#progress = ProgressBar(maxval=my.objects.count() or None).start()

output_image =  draw_bbox(im, bbox, label, config)

plt.imshow(output_image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-b4546afd47ba> in <cell line: 3>()
#       1 import cv2
#       2 import matplotlib.pyplot as plt
# ----> 3 import cvlib as cv
#       4 from cv.object_detection import draw_bbox
#       5
#
# ModuleNotFoundError: No module named 'cvlib'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
